# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('energy-dataset-full.csv')
df.head()
# Out:
#                         time  generation biomass  \
# 0  2015-01-01 00:00:00+01:00            447.0000
# 1  2015-01-01 01:00:00+01:00            449.0000
# 2  2015-01-01 02:00:00+01:00            448.0000
# 3  2015-01-01 03:00:00+01:00            438.0000
# 4  2015-01-01 04:00:00+01:00            428.0000
#
#    generation fossil brown coal/lignite  generation fossil coal-derived gas  \
# 0                              329.0000                              0.0000
# 1                              328.0000                              0.0000
# 2                              323.0000                              0.0000
# 3                              254.0000                              0.0000
# 4                              187.0000                              0.0000
#
#    generation fossil gas  generation fossil hard coal  generation fossil oil  \
# 0              4844.0000                    4821.0000               162.0000
# 1              5196.0000                    4755.0000               158.0000
# 2              4857.0000                    4581.0000               157.0000
# 3              4314.0000                    4131.0000               160.0000
# 4              4130.0000                    3840.0000               156.0000
#
#    generation fossil oil shale  generation fossil peat  generation geothermal  \
# 0                       0.0000                  0.0000                 0.0000
# 1                       0.0000                  0.0000                 0.0000
# 2                       0.0000                  0.0000                 0.0000
# 3                       0.0000                  0.0000                 0.0000
# 4                       0.0000                  0.0000                 0.0000
#
#    ...  generation waste  generation wind offshore  generation wind onshore  \
# 0  ...          196.0000                    0.0000                6378.0000
# 1  ...          195.0000                    0.0000                5890.0000
# 2  ...          196.0000                    0.0000                5461.0000
# 3  ...          191.0000                    0.0000                5238.0000
# 4  ...          189.0000                    0.0000                4935.0000
#
#    forecast solar day ahead  forecast wind offshore eday ahead  \
# 0                   17.0000                                nan
# 1                   16.0000                                nan
# 2                    8.0000                                nan
# 3                    2.0000                                nan
# 4                    9.0000                                nan
#
#    forecast wind onshore day ahead  total load forecast  total load actual  \
# 0                        6436.0000           26118.0000         25385.0000
# 1                        5856.0000           24934.0000         24382.0000
# 2                        5454.0000           23515.0000         22734.0000
# 3                        5151.0000           22642.0000         21286.0000
# 4                        4861.0000           21785.0000         20264.0000
#
#    price day ahead  price actual
# 0          50.1000       65.4100
# 1          48.1000       64.9200
# 2          47.3300       64.4800
# 3          42.2700       59.3200
# 4          38.4100       56.0400
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 29 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   time                                         35064 non-null  object
#  1   generation biomass                           35045 non-null  float64
#  2   generation fossil brown coal/lignite         35046 non-null  float64
#  3   generation fossil coal-derived gas           35046 non-null  float64
#  4   generation fossil gas                        35046 non-null  float64
#  5   generation fossil hard coal                  35046 non-null  float64
#  6   generation fossil oil                        35045 non-null  float64
#  7   generation fossil oil shale                  35046 non-null  float64
#  8   generation fossil peat                       35046 non-null  float64
#  9   generation geothermal                        35046 non-null  float64
#  10  generation hydro pumped storage aggregated   0 non-null      float64
#  11  generation hydro pumped storage consumption  35045 non-null  float64
#  12  generation hydro run-of-river and poundage   35045 non-null  float64
#  13  generation hydro water reservoir             35046 non-null  float64
#  14  generation marine                            35045 non-null  float64
#  15  generation nuclear                           35047 non-null  float64
#  16  generation other                             35046 non-null  float64
#  17  generation other renewable                   35046 non-null  float64
#  18  generation solar                             35046 non-null  float64
#  19  generation waste                             35045 non-null  float64
#  20  generation wind offshore                     35046 non-null  float64
#  21  generation wind onshore                      35046 non-null  float64
#  22  forecast solar day ahead                     35064 non-null  float64
#  23  forecast wind offshore eday ahead            0 non-null      float64
#  24  forecast wind onshore day ahead              35064 non-null  float64
#  25  total load forecast                          35064 non-null  float64
#  26  total load actual                            35028 non-null  float64
#  27  price day ahead                              35064 non-null  float64
#  28  price actual                                 35064 non-null  float64
# dtypes: float64(28), object(1)
# memory usage: 7.8+ MB

# %%
mape = np.mean(np.abs((df['total load actual'] - df['total load forecast']) / df['total load actual'])) * 100
print('MAPE of the forecasted data present in DataFrame:', mape)
# Out:
# MAPE of the forecasted data present in DataFrame: 1.096023073723821

# %%
temp = df.copy() # make temporary copy of dataframe
dataset = temp['total load actual'].dropna().values # numpy.ndarray of the actual load
dataset = dataset.astype('float32') 
dataset = np.reshape(dataset, (-1, 1)) # reshape to one feature; required for the models

scaler = MinMaxScaler(feature_range=(0, 1)) # Min Max scaler
dataset = scaler.fit_transform(dataset) # fit and transform the dataset

# Train and Test splits
train_size = int(len(dataset) * 0.80) 
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 25 # timesteps to lookback for predictions
X_train, trainY = create_dataset(train, look_back)
X_test, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
print("Shapes: \nTraining set: {}, Testing set: {}".format(X_train.shape, X_test.shape))
print("Sample from training set: \n{}".format(X_train[0]))
# Out:
# Shapes:
# Training set: (27996, 1, 25), Testing set: (6980, 1, 25)
# Sample from training set:
# [[0.31966567 0.27600765 0.20427442 0.14124662 0.09676152 0.08113521
#   0.08570558 0.10168016 0.08936191 0.11299729 0.1832071  0.23966217
#   0.26516938 0.2904153  0.2886306  0.23883522 0.22098899 0.2422303
#   0.36589193 0.43436062 0.47762692 0.5018717  0.47836685 0.38117003
#   0.39300954]]

# %% [markdown]
# Models and their MAPE
#
# Here we test various models and visualize their predictions. Models used are:
#
#     AutoRegressive
#     Moving Average
#     ARMA
#     ARIMA
#     LSTM
#
# AutoRegressive
#
# An autoregressive (AR) model predicts future behavior based on past behavior. The process is basically a linear regression of the data in the current series against one or more past values in the same series.

# %%
from statsmodels.tsa.ar_model import AR

model = AR(train)
model_fit = model.fit()

# %%
test_predict = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# invert predictions
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform(test)
print('Test Mean Absolute Error:', mean_absolute_error(Y_test, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test, test_predict)))
# Out:
# Test Mean Absolute Error: 3729.2644250787775
# Test Root Mean Squared Error: 4391.073081234294

# %%
mape = np.mean(np.abs((Y_test - test_predict) / Y_test)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 13.333375085466544

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# Moving Average
#
# The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks or any time period the trader chooses. We are taking moving average of 25 hours hence we can use the data we prepared for LSTM.

# %%
test_predict = np.mean(X_test, axis=2)
print('Test Mean Absolute Error:', mean_absolute_error(testY, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(testY, test_predict)))
# Out:
# Test Mean Absolute Error: 0.14497761
# Test Root Mean Squared Error: 0.17464507

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, testY[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# ARMA
#
# An ARMA model, or Autoregressive Moving Average model, is used to describe weakly stationary stochastic time series in terms of two polynomials. The first of these polynomials is for autoregression, the second for the moving average.

# %%
from statsmodels.tsa.arima_model import ARMA

model = ARMA(train, order=(2, 1))
model_fit = model.fit(disp=False)

# %%
test_predict = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# invert predictions
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform(test)
print('Test Mean Absolute Error:', mean_absolute_error(Y_test, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test, test_predict)))
# Out:
# Test Mean Absolute Error: 3862.9291292205826
# Test Root Mean Squared Error: 4521.711450089833

# %%
mape = np.mean(np.abs((Y_test - test_predict) / Y_test)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 13.815133664875004

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# ARIMA
#
# Auto Regressive Integrated Moving Average is a class of models that explains a given time series based on its own past values, that is, its own lags and the lagged forecast errors, so that equation can be used to forecast future values.

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(train, order=(1, 1, 1))
model_fit = model.fit(disp=False)

# %%
test_predict = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# invert predictions
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform(test)
print('Test Mean Absolute Error:', mean_absolute_error(Y_test, test_predict))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test, test_predict)))
# Out:
# Test Mean Absolute Error: 10816.588595521625
# Test Root Mean Squared Error: 11722.243289155587

# %%
mape = np.mean(np.abs((Y_test - test_predict) / Y_test)) * 100
print("Testing MAPE: {}".format(mape))
# Out:
# Testing MAPE: 35.88114053527199

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %% [markdown]
# LSTM
#
# Long short-term memory is an artificial recurrent neural network architecture used in the field of deep learning. Unlike standard feedforward neural networks, LSTM has feedback connections. It can not only process single data points, but also entire sequences of data

# %%
# making data again to remove inconsistencies
temp = df
dataset = temp['total load actual'].dropna().values #numpy.ndarray
dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 25
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=200, batch_size=70, validation_data=(X_test, Y_test),verbose=1, shuffle=False)

model.summary()
# Out:
# poch 24/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0013 - val_loss: 7.1950e-04
# Epoch 25/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 7.1088e-04
# Epoch 26/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0012 - val_loss: 7.1796e-04
# Epoch 27/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0012 - val_loss: 7.0849e-04
# Epoch 28/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0012 - val_loss: 7.6084e-04
# Epoch 29/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0012 - val_loss: 6.8382e-04
# Epoch 30/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0012 - val_loss: 6.7295e-04
# Epoch 31/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0012 - val_loss: 7.3325e-04
# Epoch 32/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 6.6624e-04
# Epoch 33/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 6.5738e-04
# Epoch 34/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0012 - val_loss: 6.5533e-04
# Epoch 35/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.4383e-04
# Epoch 36/200
# 400/400 [==============================] - 2s 6ms/step - loss: 0.0011 - val_loss: 6.9937e-04
# Epoch 37/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.5506e-04
# Epoch 38/200
# 400/400 [==============================] - 2s 4ms/step - loss: 0.0011 - val_loss: 6.6043e-04
# Epoch 39/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 7.0290e-04
# Epoch 40/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 6.5321e-04
# Epoch 41/200
# 400/400 [==============================] - 2s 4ms/step - loss: 0.0011 - val_loss: 6.4133e-04
# Epoch 42/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.2924e-04
# Epoch 43/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 6.4192e-04
# Epoch 44/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 6.3097e-04
# Epoch 45/200
# 400/400 [==============================] - 2s 4ms/step - loss: 0.0011 - val_loss: 6.4291e-04
# Epoch 46/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.4717e-04
# Epoch 47/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.3575e-04
# Epoch 48/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 6.5358e-04
# Epoch 49/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 6.3530e-04
# Epoch 50/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.4193e-04
# Epoch 51/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.4342e-04
# Epoch 52/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.3061e-04
# Epoch 53/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 6.2056e-04
# Epoch 54/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.3782e-04
# Epoch 55/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.2448e-04
# Epoch 56/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.4370e-04
# Epoch 57/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 6.2202e-04
# Epoch 58/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 6.0452e-04
# Epoch 59/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.3583e-04
# Epoch 60/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.0709e-04
# Epoch 61/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 6.4994e-04
# Epoch 62/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 6.0847e-04
# Epoch 63/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 6.3153e-04
# Epoch 64/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 6.0438e-04
# Epoch 65/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 6.2003e-04
# Epoch 66/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 5.9397e-04
# Epoch 67/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 6.0524e-04
# Epoch 68/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 7.0114e-04
# Epoch 69/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 6.2349e-04
# Epoch 70/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 6.3617e-04
# Epoch 71/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 6.3244e-04
# Epoch 72/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 6.0838e-04
# Epoch 73/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 6.0495e-04
# Epoch 74/200
# 400/400 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 6.1697e-04
# Epoch 75/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 6.0590e-04
# Epoch 76/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 6.0254e-04
# Epoch 77/200
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 6.1895e-04
# Epoch 78/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 5.9610e-04
# Epoch 79/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 6.0252e-04
# Epoch 80/200
# 400/400 [==============================] - 2s 5ms/step - loss: 0.0010 - val_loss: 6.1938e-04
# Epoch 81/200
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 5.8714e-04
# Epoch 82/200
# 400/400 [==============================] - 2s 4ms/step - loss: 0.
200
# 400/400 [==============================] - 2s 6ms/step - loss: 9.6284e-04 - val_loss: 5.4768e-04
# Epoch 178/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.5404e-04 - val_loss: 5.4736e-04
# Epoch 179/200
# 400/400 [==============================] - 1s 3ms/step - loss: 9.6514e-04 - val_loss: 5.3804e-04
# Epoch 180/200
# 400/400 [==============================] - 2s 4ms/step - loss: 9.3901e-04 - val_loss: 5.3840e-04
# Epoch 181/200
# 400/400 [==============================] - 2s 6ms/step - loss: 9.3902e-04 - val_loss: 5.7813e-04
# Epoch 182/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.5052e-04 - val_loss: 5.4776e-04
# Epoch 183/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.4340e-04 - val_loss: 5.7893e-04
# Epoch 184/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.4725e-04 - val_loss: 5.4577e-04
# Epoch 185/200
# 400/400 [==============================] - 3s 7ms/step - loss: 9.4553e-04 - val_loss: 5.7802e-04
# Epoch 186/200
# 400/400 [==============================] - 2s 6ms/step - loss: 9.3008e-04 - val_loss: 5.4584e-04
# Epoch 187/200
# 400/400 [==============================] - 2s 4ms/step - loss: 9.3668e-04 - val_loss: 5.5334e-04
# Epoch 188/200
# 400/400 [==============================] - 1s 2ms/step - loss: 9.2101e-04 - val_loss: 5.4176e-04
# Epoch 189/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.2474e-04 - val_loss: 5.7439e-04
# Epoch 190/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.4407e-04 - val_loss: 5.4628e-04
# Epoch 191/200
# 400/400 [==============================] - 1s 3ms/step - loss: 9.5632e-04 - val_loss: 5.5273e-04
# Epoch 192/200
# 400/400 [==============================] - 1s 4ms/step - loss: 9.2452e-04 - val_loss: 5.8108e-04
# Epoch 193/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.7285e-04 - val_loss: 5.6436e-04
# Epoch 194/200
# 400/400 [==============================] - 2s 4ms/step - loss: 9.2556e-04 - val_loss: 5.8079e-04
# Epoch 195/200
# 400/400 [==============================] - 1s 2ms/step - loss: 9.7268e-04 - val_loss: 5.6866e-04
# Epoch 196/200
# 400/400 [==============================] - 2s 4ms/step - loss: 9.6122e-04 - val_loss: 5.6516e-04
# Epoch 197/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.3724e-04 - val_loss: 5.7107e-04
# Epoch 198/200
# 400/400 [==============================] - 1s 3ms/step - loss: 9.2640e-04 - val_loss: 5.5164e-04
# Epoch 199/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.4844e-04 - val_loss: 5.5806e-04
# Epoch 200/200
# 400/400 [==============================] - 2s 5ms/step - loss: 9.5477e-04 - val_loss: 5.5414e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               50400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 50,501
# Trainable params: 50,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 362.98091322643467
# Train Root Mean Squared Error: 573.3510921122771
# Test Mean Absolute Error: 343.4970325013441
# Test Root Mean Squared Error: 540.8135581858394

# %%
mape_train = np.mean(np.abs((Y_train[0] - train_predict[:,0]) / Y_train[0])) * 100
mape_test = np.mean(np.abs((Y_test[0] - test_predict[:,0]) / Y_test[0])) * 100

print("Train MAPE: {}, Test MAPE: {}".format(mape_train, mape_test))
# Out:
# Train MAPE: 1.2855735179964407, Test MAPE: 1.2067667627267318

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
idx = 200
aa=[x for x in range(idx)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[0][:idx], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:idx], 'r', label="prediction")
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('TOTAL Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
